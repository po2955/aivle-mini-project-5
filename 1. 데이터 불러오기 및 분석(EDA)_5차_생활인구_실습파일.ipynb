# %% [markdown]
# # 안녕하세요^^
# # 미니 프로젝트에 오신 여러분을 환영합니다.
#
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.

# %% [markdown]
# ## 기본 데이터
#
# [기본 데이터]
# * 서울시 특정구 특정동의 생활인구 데이터입니다.
# * data2017.csv
# * data2018.csv
# * data2019.csv
# * data2020.csv
# * data2021.csv
# * data2022.csv
#
#
# * 2017~2021년은 데이터 전부(train data), 2022년은 1~6월(test data)까지 제공합니다.
#
# [변수 소개]
# * index : 날짜
#
# * 시간대 : 0 ~ 23
#
# * 총 생활 인구 수 : 생활 인구 합계
#
# * 각 성별, 연령대 별 생활 인구수

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 'data2017.csv'파일을 'df2017' 변수에 저장하고 그 Shape을 확인하세요.
# * 아래에 'Pandas'를 Import하고 'data2017.csv'파일을 불러오고 Shape을 확인하는 소스코드를 작성하고 실행해보세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import numpy as np
import pandas as pd

# %%
# 코랩 사용 시 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df2017 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/test2017.csv', sep = ',', index_col=0)

# %%
# 데이터 프레임의 Shape을 확인합니다.
df2017.shape
# Out:
# (8760, 31)

# %% [markdown]
# ---

# %% [markdown]
# # 2. 추가 데이터 불러오기

# %% [markdown]
# #### [실습문제2] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data2018.csv' ~ 'data2021.csv'를 df18 ~ df21로 각각 불러오고, 이미 불러와 있던 df17을 포함하여 'df_total'로 합쳐보세요. 그리고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/test2018.csv', sep = ',', index_col=0)
df2019 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/test2019.csv', sep = ',', index_col=0)
df2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/test2020.csv', sep = ',', index_col=0)
df2021 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/test2021.csv', sep = ',', index_col=0)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total = pd.concat([df2017, df2018, df2019, df2020, df2021])

# %%
# 데이터 프레임의 Shape을 확인합니다.
df_total.shape
# Out:
# (43512, 31)

# %% [markdown]
# #### [실습문제3] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data2022.csv'를 df_test로 불러오고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/data2022.csv', sep = ',', index_col = 0)

# %%
# 데이터 프레임의 Shape을 확인합니다.
df_test.shape
# Out:
# (4344, 30)

# %%
df_total.head()
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  43922.2281       953.7652         627.7225
# 1  20170101      1  43763.4929       962.2909         633.3292
# 2  20170101      2  43561.5708       932.2939         613.6027
# 3  20170101      3  43928.9929       926.3617         609.7009
# 4  20170101      4  44150.2973       922.8893         607.4184
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         927.6134        2025.0630        2278.7336        1744.8161
# 1         970.6215        2045.7002        2412.6287        1765.7725
# 2         964.3505        2057.3601        2419.0941        1734.0569
# 3         983.2400        2100.5071        2480.1898        1780.3833
# 4         990.0534        2128.2729        2531.6549        1774.7853
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1713.6754  ...        2060.1511        1734.3805        1713.3332
# ...

# %% [markdown]
# #### [실습문제4] 데이터 확인
# * df_total와 df_test 데이터를 head, tail. describe, info 등을 활용하여 확인하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
print(df_total.info())
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43512 entries, 0 to 8759
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            43512 non-null  int64
#  1   시간대구분            43512 non-null  int64
#  2   총생활인구수           43512 non-null  float64
#  3   남자0세부터9세생활인구수    43512 non-null  float64
#  4   남자10세부터14세생활인구수  43512 non-null  float64
#  5   남자15세부터19세생활인구수  43512 non-null  float64
#  6   남자20세부터24세생활인구수  43512 non-null  float64
#  7   남자25세부터29세생활인구수  43512 non-null  float64
#  8   남자30세부터34세생활인구수  43512 non-null  float64
#  9   남자35세부터39세생활인구수  43512 non-null  float64
#  10  남자40세부터44세생활인구수  43512 non-null  float64
#  11  남자45세부터49세생활인구수  43512 non-null  float64
#  12  남자50세부터54세생활인구수  43512 non-null  float64
#  13  남자55세부터59세생활인구수  43512 non-null  float64
#  14  남자60세부터64세생활인구수  43512 non-null  float64
#  15  남자65세부터69세생활인구수  43512 non-null  float64
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
print(df_total.describe())
print(df_test.describe())
# Out:
#               기준일ID         시간대구분        총생활인구수  남자0세부터9세생활인구수  \
# count  4.351200e+04  43512.000000  43512.000000   43512.000000
# mean   2.019067e+07     11.500000  40764.541744     921.608027
# std    1.419499e+04      6.922266   3715.404186     152.320273
# min    2.017010e+07      0.000000  17151.568200     372.913900
# 25%    2.018033e+07      5.750000  37917.393025     814.411425
# 50%    2.019063e+07     11.500000  40169.603850     892.195000
# 75%    2.020100e+07     17.250000  43514.610950     999.298425
# max    2.021123e+07     23.000000  63617.153900    1601.056000
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# count     43512.000000     43512.000000     43512.000000     43512.000000
# mean        606.575476       832.968472      2085.119648      2339.973284
# std         100.167872       132.507679       525.985477       427.471543
# min         245.747200       318.987800       890.752300      1101.848300
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# ---

# %% [markdown]
# # 3. 데이터 분석하기
# ## EDA for Feature Engineering
#
# * EDA는 명확한 목적하에, 반드시 workflow에 도움이 되는 결과를 도출해야 함.
# * EDA를 검색해봐도 좋음.
#
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 관측치들의 패턴 탐색
#   * 잘못된 자료들을 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
df_total.head()
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  43922.2281       953.7652         627.7225
# 1  20170101      1  43763.4929       962.2909         633.3292
# 2  20170101      2  43561.5708       932.2939         613.6027
# 3  20170101      3  43928.9929       926.3617         609.7009
# 4  20170101      4  44150.2973       922.8893         607.4184
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         927.6134        2025.0630        2278.7336        1744.8161
# 1         970.6215        2045.7002        2412.6287        1765.7725
# 2         964.3505        2057.3601        2419.0941        1734.0569
# 3         983.2400        2100.5071        2480.1898        1780.3833
# 4         990.0534        2128.2729        2531.6549        1774.7853
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1713.6754  ...        2060.1511        1734.3805        1713.3332
# ...

# %% [markdown]
# #### [실습문제5] 데이터 형태 변경하기
# * df_total, df_test의 index를 리셋 하고, ['기준일ID']에 to_datetime 함수를 사용하여 데이터 형태를 변경하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'], format = "%Y%m%d")

# %%
# df_test['기준일ID'] = pd.to_datetime(df_test['기준일ID'], format = "%Y%m%d")

# %%
df_total.head()

# %% [markdown]
# #### [실습문제6] 데이터 분포 알아보기
# * df_total 및 df_test의 '총생활인구수' 변수를 기준으로 각종 Chart를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
sns.jointplot(x = df_total['시간대구분'], y = df_total['총생활인구수'])
plt.show()

# %%
import scipy.stats as spst
spst.pearsonr(df_total['총생활인구수'],df_total['시간대구분'])

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1.
# 2.
# 3.

# %% [markdown]
# ## 다음 단계를 위해서 데이터를 저장하겠습니다.

# %%
# CSV로 저장
df_total.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_total.csv', index=False)
df_test.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_test.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-c33de722f13c> in <module>
#       1 # CSV로 저장
#       2 df_total.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_total.csv', index=False)
# ----> 3 df_test.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_test.csv', index=False)
#
# NameError: name 'df_test' is not defined

# %% [markdown]
# # 4. (참고) 시계열 분석 기초 (Stationary / Normality)
#
# * 아래 주어진 코드를 기반으로 해당 데이터가 정상성과 정규성을 충족 하는지 확인해봅시다

# %% [markdown]
# #### [실습문제7] 정상성 분석
# * df_total['총생활인구수'] 데이터가 정상성을 띄는지 확인해보도록 하겠습니다
#
# * 정상성을 띈다 = 시계열 데이터의 평균과 분산이 일정하다.
#     - Dickey Fuller test 를 활용합니다
#     - Stationary (p-value < 0.05)
#
# ---
#
# * 귀무가설 : H0 : 시계열 데이터에 unit root를 포함한다 : nonstatinary / 정상 시계열이 아니다.
# * 대립가설 : H1 : 시계열 데이터에 unit root를 포함하지 않는다 : 정상 시계열이다.
# ---

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(y):
    dftest = adfuller(y, autolag='AIC')
    # autolag 'AIC' : 검정 AR 모형의 차수를 자동으로 결정
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value ({})'.format(key)] = value
    print(dfoutput)

# %%
adf_test(df_total['총생활인구수'])

# %%
# test statistic 검정 통계량 - 회귀 분석의 결과로 나타나는 계수
# p-value : p-value 추정치
# # of lags : 사용된 시차의 수(used lags)
# # of observations : 분석에 사용된 자료의 수

# critical values : 1%, 5%, 10%수준에 해당되는 검정 통계량의 값

# %% [markdown]
# #### [실습문제8] 정규성 분석
# * df_total['총생활인구수'] 데이터가 정규성을 띄는지 확인해보도록 하겠습니다
#
# * 정규성을 띈다 = 데이터의 분포가 정규분포를 이룬다.
#     * Shapiro test 를 활용합니다
#     * Normality (p-value > 0.05)
#
# ---
# * 귀무가설 : H0 : 시계열 데이터가 정규성을 충족한다.
# * 대립가설 : H1 : 시계열 데이터가 정규성을 충족하지 않는다.
# ---

# %%
from scipy import stats
from scipy.stats import shapiro
shapiro_test = stats.shapiro(df_total['총생활인구수'])
shapiro_test

# %%
# shapiro test의 특징 : 데이터 수가 5000을 초과 하는 경우, 
#                      정규성 검정에 대한 p-value를 담보하지 못한다.(통계적 유의성이 떨어진다.)

# 시계열 데이터가 정규성을 충족하지 않습니다.

# %%
from scipy.stats import anderson
anderson(df_total['총생활인구수'])

# %%
df_total = pd.concat([df2017, df2018, df2019, df2020, df2021])

# %%
df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'], format = "%Y%m%d")
# df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'])

# %%
df_total['year'] = df_total['기준일ID'].dt.year
df_total['month'] = df_total['기준일ID'].dt.month
df_total['day'] = df_total['기준일ID'].dt.day
df_total['hour'] = df_total['시간대구분']

# %%
df_total.drop('시간대구분',axis = 1, inplace = True)
df_total.drop('기준일ID',axis = 1, inplace = True)

# %%
df_total = df_total[['총생활인구수','year','month','day','hour']]
df_total['총생활인구수_1416'] = df_total['총생활인구수'].shift(1416)
df_total['총생활인구수_1416_7'] = df_total['총생활인구수'].shift(1584)
df_total['총생활인구수_1416_30'] = df_total['총생활인구수'].shift(2136)
df_total = df_total.dropna()
df_total = df_total.reset_index()
df_total.drop('index', inplace = True, axis = 1)

# %%
df_total.head()
# Out:
#        총생활인구수  year  month  day  hour  총생활인구수_1416  총생활인구수_1416_7  \
# 0  43597.0564  2017      3   31     0   46589.2983     48850.1513
# 1  43969.4336  2017      3   31     1   46801.7668     48891.8935
# 2  44356.9712  2017      3   31     2   47001.0253     49177.4859
# 3  44562.6872  2017      3   31     3   47077.8881     49317.3734
# 4  44724.3425  2017      3   31     4   47603.6497     48129.1089
#
#    총생활인구수_1416_30
# 0      43922.2281
# 1      43763.4929
# 2      43561.5708
# 3      43928.9929
# 4      44150.2973

# %%
from sklearn.model_selection import train_test_split
x = df_total.drop('총생활인구수', axis = 1)
y = df_total.loc[:, '총생활인구수']

train_x, test_x, train_y, test_y = train_test_split(x,y, test_size = 0.2, shuffle = False)

# %%
params = {'learning_rate':np.linspace(0.026896551724137928,0.03,5),
              'n_estimators':[128,129,130, 131],
          'max_depth' : [4],
          }

# %%
model2 = XGBRegressor()
model2_gs = GridSearchCV(model2, params, cv = tscv, verbose = 3)
model2_gs.fit(train_x,train_y)
# pred2 = model2.predict(test_x)
# print('RMSE :', mean_squared_error(test_y, pred2, squared = False))
# print('r2_score :', r2_score(test_y, pred2))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [06:14:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.026896551724137928, max_depth=4, n_estimators=128;, score=0.527 total time=   0.4s
# [06:14:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.026896551724137928, max_depth=4, n_estimators=128;, score=0.355 total time=   0.7s
# [06:14:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.026896551724137928, max_depth=4, n_estimators=128;, score=0.630 total time=   1.0s
# [06:14:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
model2 = XGBRegressor(learning_rate=0.026896551724137928, max_depth=4, n_estimators=130)
# model2_gs = GridSearchCV(model2, params, cv = 5, verbose = 3)
model2.fit(train_x,train_y)
pred2 = model2.predict(test_x)
print('RMSE :', mean_squared_error(test_y, pred2, squared = False))
print('r2_score :', r2_score(test_y, pred2))
# Out:
# [06:41:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE : 1083.7578770061784
# r2_score : 0.6727105525919821

# %%
print(len(pred2))
pred2 = pred2[6860:8276][:]
print(len(pred2))
# Out:
# 8276
# 1416

# %%
pred2 = pred2 + 50

# %%
# submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/submission.csv')
submission['count'] = pred2
print(submission.head())
submission.to_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/submission.csv',index = False)
# Out:
#    id         count
# 0   0  38791.011719
# 1   1  38791.011719
# 2   2  38801.886719
# 3   3  38727.675781
# 4   4  38621.730469

# %%
# df_total['총생활인구수_1416'] = df_total['총생활인구수'].shift(1416)

# %%
df_total['']

# %%
# df_total = df_total.dropna()

# %%
# df_total = df_total.reset_index()

# %%
# df_total.drop('index', inplace = True, axis = 1)

# %%
from sklearn.model_selection import train_test_split
x = df_total.drop('총생활인구수', axis = 1)
y = df_total.loc[:, '총생활인구수']

train_x, test_x, train_y, test_y = train_test_split(x,y, test_size = 0.2, shuffle = False)

# %%
model2 = XGBRegressor(learning_rate=0.026896551724137928, max_depth=4, n_estimators=130)
# model2_gs = GridSearchCV(model2, params, cv = 5, verbose = 3)
model2.fit(train_x,train_y)
pred2 = model2.predict(test_x)
print('RMSE :', mean_squared_error(test_y, pred2, squared = False))
print('r2_score :', r2_score(test_y, pred2))
# Out:
#        year  month  day  hour  총생활인구수_1416
# 0      2017      3    1     0   43922.2281
# 1      2017      3    1     1   43763.4929
# 2      2017      3    1     2   43561.5708
# 3      2017      3    1     3   43928.9929
# 4      2017      3    1     4   44150.2973
# ...     ...    ...  ...   ...          ...
# 33671  2021      1   14    23   42451.5158
# 33672  2021      1   15     0   42527.5745
# 33673  2021      1   15     1   42548.8748
# 33674  2021      1   15     2   42553.2900
# 33675  2021      1   15     3   42582.5377
#
# [33676 rows x 5 columns]

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from numpy import square
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from xgboost import XGBRFRegressor
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
params_1 = {'n_estimators' : range(130, 180, 10), 'max_features' : range(1,10)}

# %%
model1 = RandomForestRegressor(n_estimators=150, max_features=2)
# model1_gs = GridSearchCV(model1, params_1, cv= 5, verbose = 3)
model1.fit(train_x, train_y)
pred1 = model1.predict(test_x)

# %%
print('RMSE :', mean_squared_error(test_y, pred1, squared = False))
print('r2_score :', r2_score(test_y, pred1))
# print(model1_.best_params_, model1_gs.best_score_)
# Out:
# RMSE : 1733.0248645522581
# r2_score : 0.1635211737324468

# %%
from sklearn.model_selection import TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)

# %%
params = {'learning_rate':np.linspace(0.01,0.5,30),
              'n_estimators':range(100,130,10),
          'max_depth' : range(2,6),
          }

# %%
model2 = XGBRegressor(learning_rate=0.026896551724137928, max_depth=4, n_estimators=130)
# model2_gs = GridSearchCV(model2, params, cv = 5, verbose = 3)
model2.fit(train_x,train_y)
pred2 = model2.predict(test_x)
# Out:
# [04:54:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print(model2_gs.best_params_, model2_gs.best_score_)
# Out:
# {'learning_rate': 0.04379310344827586, 'max_depth': 4, 'n_estimators': 100} 0.5999240668170374

# %%
model2_1 = XGBRegressor(learning_rate = 0.04379310344827586, n_estimators = 100)
model2_1.fit(train_x, train_y)
pred2_1 = model2_1.predict(test_x)
# Out:
# [04:36:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print('RMSE :', mean_squared_error(test_y, pred2, squared = False))
print('r2_score :', r2_score(test_y, pred2))
# Out:
# RMSE : 1098.4544710585396
# r2_score : 0.663945677095996

# %%
print('RMSE :', mean_squared_error(test_y, pred2_1, squared = False))
print('r2_score :', r2_score(test_y, pred2_1))
# Out:
# RMSE : 1393.329620794864
# r2_score : 0.4593040652342405

# %%
model3 = XGBRFRegressor()
model3 = model3.fit(train_x, train_y)
pred3 = model3.predict(test_x)
# Out:
# [02:12:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print('RMSE :', mean_squared_error(test_y, pred2, squared = False))
print('r2_score :', r2_score(test_y, pred2))
# Out:
# RMSE : 2372.663084982272
# r2_score : -0.5678969355683756

# %%
pred2 = pred2[7004:8420][:]
len(pred2)
# Out:
# 1416

# %%
submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/submission.csv')

# %%
submission['count'] = pred2

# %%
pred2 = pred2[7004:8420][:]
submission['count'] = pred2
print(submission.head())
submission.to_csv('/content/drive/MyDrive/Colab Notebooks/aivle-school-5th-mini-project/submission.csv',index = False)
# Out:
#    id         count
# 0   0  39139.226562
# 1   1  39139.226562
# 2   2  39075.476562
# 3   3  38932.300781
# 4   4  38742.257812

# %%
pred2_1
# Out:
# array([39619.957, 39690.39 , 39760.39 , ..., 36462.836, 37172.16 ,
#        40031.832], dtype=float32)

# %%
df_total_1 = df_total.loc[(df_total['month'] == 1) | (df_total['month'] == 2),]
# df_test_1 = df_test.loc[(df_test['month'] == 1) | (df_test['month'] == 2),]

# %%
from sklearn.model_selection import train_test_split
x_1 = df_total_1.drop('총생활인구수', axis = 1)
y_1 = df_total_1.loc[:, '총생활인구수']

train_x_1, test_x_1, train_y_1, test_y_1 = train_test_split(x_1,y_1, test_size = 0.2, shuffle = False)

# %%
model1_1 = RandomForestRegressor()
model1_1.fit(train_x_1, train_y_1)
pred1_1 = model1_1.predict(test_x_1)
print('RMSE :', mean_squared_error(test_y_1, pred1_1, squared = False))
print('r2_score :', r2_score(test_y_1, pred1_1))
# Out:
# RMSE : 1759.9921995480327
# r2_score : 0.21709587879532932

# %%
model2_1 = XGBRegressor()
model2_1.fit(train_x_1, train_y_1)
pred2_1 = model2_1.predict(test_x_1)
print('RMSE :', mean_squared_error(test_y_1, pred2_1, squared = False))
print('r2_score :', r2_score(test_y_1, pred2_1))
# Out:
# [02:10:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE : 1662.4989182933987
# r2_score : 0.30143015273095075

# %%
model3_1 = XGBRFRegressor()
model3_1.fit(train_x_1, train_y_1)
pred3_1 = model3_1.predict(test_x_1)
print('RMSE :', mean_squared_error(test_y_1, pred3_1, squared = False))
print('r2_score :', r2_score(test_y_1, pred3_1))
# Out:
# [02:11:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE : 1592.9731055030043
# r2_score : 0.3586368842763755

# %%
model4_1 = LinearRegression()
model4_1.fit(train_x_1, train_y_1)
pred4_1 = model4_1.predict(test_x_1)
print('RMSE :', mean_squared_error(test_y_1, pred4_1, squared = False))
print('r2_score :', r2_score(test_y_1, pred4_1))
# Out:
# RMSE : 1960.7501131089232
# r2_score : 0.02830136937419847

# %%
from sklearn.ensemble import AdaBoostRegressor
model_a = AdaBoostRegressor()
model_a.fit(train_x, train_y)
pred_a = model_a.predict(test_x)
print('RMSE :', mean_squared_error(test_y, pred_a, squared = False))
print('r2_score :', r2_score(test_y, pred_a))
# Out:
# RMSE : 2805.887661932308
# r2_score : -1.1927338618459054
