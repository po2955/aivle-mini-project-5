# %% [markdown]
# # 안녕하세요^^
# # AIVLE 미니 프로젝트에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # (실습준비) 데이터 불러오기부터
#
# * 17년도부터 21년도 까지의 데이터를 train set, 22년도의 6개월치 데이터를 test set 으로 설정합니다.

# %%
# 코랩 사용 시 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-98760a24ad9f> in <module>
#       1 # 코랩 사용 시 구글 드라이브 연결
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     104       timeout_ms=timeout_ms,
#     105       ephemeral=True,
# --> 106       readonly=readonly)
#     107
#     108
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123   if ephemeral:
#     124     _message.blocking_request(
# --> 125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#     127   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
import pandas as pd

# 학습 데이터 로딩
df_total = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_total.csv',sep = ',', index_col = 0)
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_test.csv', sep=',')

# %%
df_total.head()
# Out:
#             기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# index
# 0      2017-01-01      0  31535.2200      1945.4402         566.4588
# 1      2017-01-01      1  31188.9174      1930.4766         562.1018
# 2      2017-01-01      2  31240.4974      1921.1864         559.3965
# 3      2017-01-01      3  31442.4314      1946.4476         566.7525
# 4      2017-01-01      4  31922.7751      1953.7713         568.8845
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# index
# 0             631.5581         991.9184        1297.1287        1223.1529
# 1             625.2151        1030.6281        1307.7381        1183.0956
# 2             658.7463        1058.7082        1311.9591        1186.2600
# 3             649.0804        1057.9119        1324.2638        1202.1250
# 4             623.2087        1063.2557        1342.9146        1209.2680
#
#        남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# ...

# %%
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_test.csv', sep=',')

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 전처리

# %% [markdown]
# #### [실습문제1] 열 추가
# * 기존 '기준일ID'열에서 날짜 데이터를 추출하여 새로운 열로 추가 합니다.
#     - pd.to_datetime() 함수를 사용해 '기준일ID'열을 datetime 형식으로 변경하겠습니다.
#     - year, month, day 열로 기존 데이터 프레임에 연월일 정보를 저장합니다.
#     - 데이터 프레임 열에 대해 날짜 정보를 얻을 때에는 **dt.year**, **dt.month**, **dt.day** 속성을 사용합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total.tail()
# Out:
#            총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  남자15세부터19세생활인구수  \
# index
# 43507  33060.4555      1858.2611         541.0746         605.9080
# 43508  32360.1898      2093.8808         609.6807         612.5326
# 43509  31417.3991      1983.6728         577.5909         639.2174
# 43510  30763.0563      2028.3314         590.5941         654.0295
# 43511  30404.2740      1903.8825         554.3582         615.0753
#
#        남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  \
# index
# 43507         781.6602        1342.6763        1435.1080        1678.8904
# 43508         768.8351        1323.7124        1479.1382        1654.5005
# 43509         779.6693        1187.6783        1375.6785        1600.9946
# 43510         790.1638        1133.6311        1362.0266        1548.7366
# 43511         772.8499        1136.6157        1295.0434        1549.1984
#
#        남자40세부터44세생활인구수  남자45세부터49세생활인구수  ...  여자35세부터39세생활인구수  \
# ...

# %%
df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'])

df_test['기준일ID'] = pd.to_datetime(df_test['기준일ID'])

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total['year'] = df_total['기준일ID'].dt.year
df_test['year'] = df_test['기준일ID'].dt.year

df_total['month'] = df_total['기준일ID'].dt.month
df_test['month'] = df_test['기준일ID'].dt.month

df_total['day'] = df_total['기준일ID'].dt.day
df_test['day'] = df_test['기준일ID'].dt.day

# %% [markdown]
# #### [실습문제2] 불필요한 열 제거 및 열 이름 변경
# * df_total과 df_test에서 '총생활인구수'외에 불필요한 열을 제거 하도록 하겠습니다.
# * 시간 데이터를 남기고, '시간대구분' column 을 'hour'로 rename 하도록 하겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total['hour'] = df_total['시간대구분']
df_total.drop('시간대구분',axis = 1, inplace = True)
df_test['hour'] = df_test['시간대구분']
df_test.drop('시간대구분',axis = 1, inplace = True)
df_total.drop('기준일ID',axis = 1, inplace = True)
df_test.drop('기준일ID',axis = 1, inplace = True)

# %%
df_total = df_total[['총생활인구수','year','month','day','hour']]
df_test = df_test[['총생활인구수','year','month','day','hour']]

# %%
df_test.tail()
# Out:
#           총생활인구수  year  month  day  hour
# 4339  32969.6040  2022      6   30    19
# 4340  31014.6597  2022      6   30    20
# 4341  30923.2923  2022      6   30    21
# 4342  30509.5463  2022      6   30    22
# 4343  31184.8763  2022      6   30    23

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total = df_total[['총생활인구수','year','month','day','hour']]

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43512 entries, 0 to 43511
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   총생활인구수           43512 non-null  float64
#  1   year             43512 non-null  int64
#  2   month            43512 non-null  int64
#  3   day              43512 non-null  int64
#  4   hour             43512 non-null  int64
#  5   총생활인구수_lag_1416  42096 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 2.3 MB

# %%
import numpy as np
df_total.tail()
# Out:
#            총생활인구수  year  month  day  hour  총생활인구수_lag_1416
# index
# 43507  33060.4555  2021     12   31    19       34554.6229
# 43508  32360.1898  2021     12   31    20       33506.8350
# 43509  31417.3991  2021     12   31    21       32323.8287
# 43510  30763.0563  2021     12   31    22       31769.3180
# 43511  30404.2740  2021     12   31    23       32503.2263

# %% [markdown]
# #### [실습문제3] 시프트 & 롤링
# * shift()를 활용하여 이동할 행 수를 지정합니다.
# * rolling()을 활용하여 추가할 이동평균 수를 지정합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# df_total['총생활인구수_lag_1416'] = df_total['총생활인구수'].shift(1416)
# df_total['총생활인구수_lag_7'] = df_total['총생활인구수'].shift(7)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### [실습문제4] 결측치 처리 및 불필요한 열 제거
# * 롤링 & 시프트 과정에서 발생한 결측치를 처리하도록 하겠습니다.
# * 불필요한 열을 추가로 제거 하겠습니다.(시간 관련 행들)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total = df_total.dropna()
# df_total.drop(['level_0'],axis = 1, inplace = True)
df_total
# Out:
#            총생활인구수  year  month  day  hour  총생활인구수_lag_1416
# index
# 1416   31209.1023  2017      3    1     0       31535.2200
# 1417   30334.7708  2017      3    1     1       31188.9174
# 1418   30558.3055  2017      3    1     2       31240.4974
# 1419   30789.1289  2017      3    1     3       31442.4314
# 1420   31420.6076  2017      3    1     4       31922.7751
# ...           ...   ...    ...  ...   ...              ...
# 43507  33060.4555  2021     12   31    19       34554.6229
# 43508  32360.1898  2021     12   31    20       33506.8350
# 43509  31417.3991  2021     12   31    21       32323.8287
# 43510  30763.0563  2021     12   31    22       31769.3180
# 43511  30404.2740  2021     12   31    23       32503.2263
#
# [42096 rows x 6 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### [실습문제5] train, test 데이터 나누기
# * df_total과 df_test를 각각 train_x, train_y, test_x, test_y 로 나누어 주세요.
# * 인덱스를 리셋 해주세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
from sklearn.model_selection import train_test_split
x = df_total.drop('총생활인구수', axis = 1)
y = df_total.loc[:, '총생활인구수']

train_x, test_x, train_y, test_y = train_test_split(x,y, test_size = 0.2, shuffle = False)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# Out:
#        year  month  day  hour  총생활인구수_lag_1  총생활인구수_lag_7
# 34804  2021      1    3    11    33284.1112    31722.0167
# 34805  2021      1    3    12    32879.9602    31942.3392
# 34806  2021      1    3    13    33506.0451    32110.8386
# 34807  2021      1    3    14    33269.5357    32682.0765
# 34808  2021      1    3    15    33571.7711    33040.4011
# ...     ...    ...  ...   ...           ...           ...
# 43500  2021     12   31    19    35883.1874    38306.0838
# 43501  2021     12   31    20    33060.4555    39452.9085
# 43502  2021     12   31    21    32360.1898    38546.9114
# 43503  2021     12   31    22    31417.3991    37018.4693
# 43504  2021     12   31    23    30763.0563    36488.7566
#
# [8701 rows x 6 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 다음 단계를 위해서 데이터를 저장하겠습니다.

# %%
# CSV로 저장
train_x.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/train_x.csv', index = False)
train_y.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/train_y.csv', index = False)
test_x.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/test_x.csv', index = False)
test_y.to_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/test_y.csv', index = False)

# %%
df_total_1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_total.csv',sep = ',', index_col = 0)
df_test_1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니프로젝트5차_생활인구 4_5일차/df_test.csv', sep=',')

# %%
df_total_1['기준일ID'] = pd.to_datetime(df_total_1['기준일ID'])
df_test_1['기준일ID'] = pd.to_datetime(df_test_1['기준일ID'])

# %%
df_total_1['year'] = df_total_1['기준일ID'].dt.year
df_test_1['year'] = df_test_1['기준일ID'].dt.year

df_total_1['month'] = df_total_1['기준일ID'].dt.month
df_test_1['month'] = df_test_1['기준일ID'].dt.month

df_total_1['day'] = df_total_1['기준일ID'].dt.day
df_test_1['day'] = df_test_1['기준일ID'].dt.day

# %%
df_total_1['hour'] = df_total_1['시간대구분']
df_total_1.drop('시간대구분',axis = 1, inplace = True)
df_test_1['hour'] = df_test_1['시간대구분']
df_test_1.drop('시간대구분',axis = 1, inplace = True)
df_total_1.drop('기준일ID',axis = 1, inplace = True)
df_test_1.drop('기준일ID',axis = 1, inplace = True)

# %%
df_total_1 = df_total_1[['총생활인구수','year','month','day','hour']]
df_test_1 = df_test_1[['총생활인구수','year','month','day','hour']]

# %%
df_total_1 = df_total_1.loc[(df_total_1['month'] == 1) | (df_total_1['month'] == 2),]
df_test_1 = df_test_1.loc[(df_test_1['month'] == 1) | (df_test_1['month'] == 2),]

# %%
# df_test_1.loc[(df_total_1['day']==31) & (df_total_1['month'] == 1), ]

# %%
# df_test_1.loc[(df_test_1['day']==31) & (df_test_1['month'] == 1), ]

# %%
target = '총생활인구수'
a = df_total_1.drop(target, axis = 1)

# %%
test_y.shape
# Out:
# (1416,)

# %%
a = a.sample()
# Out:
# (7104, 4)

# %%
test_x = test_x.sort_values('index')

# %%
train_x = df_total_1.drop(target, axis = 1)
train_y = df_total_1.loc[:, target]
test_x = a.sample(n=1416)
test_y = df_test_1.loc[:, target]

# %%
test_x.shape
# Out:
# (1416, 4)

# %%
test_x.shape
# Out:
# (1421, 4)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from numpy import square
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from xgboost import XGBRFRegressor
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
model = RandomForestRegressor()
model.fit(train_x, train_y)
pred = model.predict(test_x)

# %%
print('RMSE :', mean_squared_error(test_y, pred, squared = False))
print('r2_score :', r2_score(test_y, pred))
# Out:
# RMSE : 5409.974684058263
# r2_score : -3.096446647963928

# %%
model2 = XGBRegressor()
model2.fit(train_x, train_y)
pred2 = model2.predict(test_x)
# Out:
# [07:52:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print('RMSE :', mean_squared_error(test_y, pred2, squared = False))
print('r2_score :', r2_score(test_y, pred2))
# Out:
# RMSE : 5200.02203255563
# r2_score : -2.7846629164045265

# %%
model3 = XGBRFRegressor()
model3.fit(train_x, train_y)
pred3 = model3.predict(test_x)
# Out:
# [07:52:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print('RMSE :', mean_squared_error(test_y, pred3, squared = False))
print('r2_score :', r2_score(test_y, pred3))
# Out:
# RMSE : 4633.7243645482
# r2_score : -2.005226640339403

# %%
model4 = LinearRegression()
model4.fit(train_x, train_y)
pred4= model4.predict(test_x)

# %%
print('RMSE :', mean_squared_error(test_y, pred4, squared = False))
print('r2_score :', r2_score(test_y, pred4))
# Out:
# RMSE : 3946.970862782804
# r2_score : -1.180442698794439

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
# 함수 만들고
train_x_s = scaler.fit_transform(train_x)
test_x_s = scaler.fit_transform(test_x)

# # 변환시키기
# train_x = scaler.transform(train_x)
# test_x = scaler.transform(test_x)

# %%
from sklearn.svm import SVC, SVR

# %%
model5 = SVR()
model5.fit(train_x_s, train_y)
pred5 = model5.predict(test_x_s)

# %%
print('RMSE :', mean_squared_error(test_y, pred5, squared = False))
print('r2_score :', r2_score(test_y, pred5))
# Out:
# RMSE : 3399.4649092582667
# r2_score : -0.6174764360665592

# %%
from sklearn.linear_model import Ridge

model6 = Ridge(alpha=1,
                 solver="cholesky",
                 random_state=42)
model6.fit(train_x_s,train_y)
pred6 = model6.predict(test_x_s)   # 새로운 샘플에 대한 예측

# %%
print('RMSE :', mean_squared_error(test_y, pred6, squared = False))
print('r2_score :', r2_score(test_y, pred6))
# Out:
# RMSE : 3946.207952215143
# r2_score : -1.1795998640903065

# %%
from sklearn.linear_model import SGDRegressor
model7 = SGDRegressor()
model7.fit(train_x_s, train_y)
pred7 = model7.predict(test_x_s)

# %%
print('RMSE :', mean_squared_error(test_y, pred7, squared = False))
print('r2_score :', r2_score(test_y, pred7))
# Out:
# RMSE : 3992.1093090657655
# r2_score : -1.2305999388484299

# %%
from sklearn.linear_model import Lasso
model8 = Lasso()
model8.fit(train_x_s, train_y)
pred8 = model8.predict(test_x_s)

# %%
print('RMSE :', mean_squared_error(test_y, pred8, squared = False))
print('r2_score :', r2_score(test_y, pred8))
# Out:
# RMSE : 3945.381890592687
# r2_score : -1.1786874462077406

# %% [markdown]
# ---
